# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.randn(N)
y = np.random.randn(N)
area = np.pi * (15*np.random.rand(N))**2

plt.scatter(x, y, s=area, alpha=0.5)
plt.show()

# %% [markdown]
# np.rank? testing

# %%
pwd
# Out:
# u'/home/ajoshi/pdev/optmon'

# %%
run test.py

# %%
run test.py
# Out:
# Testing iPython Notebook

# %%
cd ../docs/QuantEcon.py-master/examples/
# Out:
# /home/ajoshi/pdev/docs/QuantEcon.py-master/examples

# %%
ls w*
# Out:
# wb_download.py  web_network.py  white_noise_plot.py

# %%
run white_noise_plot.py
